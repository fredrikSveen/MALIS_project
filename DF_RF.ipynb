# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, balanced_accuracy_score

# %%
#Import dataframe from JSON file
jsonStr = "parameters_df.json"
df = pd.read_json(jsonStr, orient ='index')
print(df.head)
# Out:
# <bound method NDFrame.head of                                                    red   green    blue  \
# data/12910/0/12910_idx5_x3001_y701_class0.png   2.8792  2.7112  2.8076
# data/12910/0/12910_idx5_x1501_y401_class0.png   2.7392  2.7464  2.0908
# data/12910/0/12910_idx5_x2251_y1101_class0.png  1.1296  2.6620  2.2704
# data/12910/0/12910_idx5_x2551_y1151_class0.png  1.9812  2.8940  2.2452
# data/12910/0/12910_idx5_x2001_y101_class0.png   2.8660  3.0032  2.5404
# ...                                                ...     ...     ...
# data/13666/1/13666_idx5_x901_y1101_class1.png   2.1980  2.3572  2.7020
# data/13666/1/13666_idx5_x1051_y1001_class1.png  2.6968  2.4552  2.5280
# data/13666/1/13666_idx5_x1051_y1151_class1.png  2.4272  2.8244  2.5152
# data/13666/1/13666_idx5_x1051_y1051_class1.png  2.5724  2.3860  2.5444
# data/13666/1/13666_idx5_x901_y1151_class1.png   2.7212  2.7648  3.0000
#
#                                                     gray  gray_var  edges  \
# data/12910/0/12910_idx5_x3001_y701_class0.png   0.755730  0.003960     83
# data/12910/0/12910_idx5_x1501_y401_class0.png   0.483340  0.009377    350
# data/12910/0/12910_idx5_x2251_y1101_class0.png  0.799321  0.001401     14
# data/12910/0/12910_idx5_x2551_y1151_class0.png  0.824825  0.001107      0
# data/12910/0/12910_idx5_x2001_y101_class0.png   0.675241  0.005805    187
# ...                                                  ...       ...    ...
# data/13666/1/13666_idx5_x901_y1101_class1.png   0.659095  0.002654     31
# data/13666/1/13666_idx5_x1051_y1001_class1.png  0.623201  0.004284    136
# data/13666/1/13666_idx5_x1051_y1151_class1.png  0.648590  0.002005     28
# data/13666/1/13666_idx5_x1051_y1051_class1.png  0.632355  0.003022     70
# data/13666/1/13666_idx5_x901_y1151_class1.png   0.655819  0.004799     97
#
#                                                 ridges  group
# data/12910/0/12910_idx5_x3001_y701_class0.png     1292      0
# data/12910/0/12910_idx5_x1501_y401_class0.png     1297      0
# data/12910/0/12910_idx5_x2251_y1101_class0.png    1315      0
# data/12910/0/12910_idx5_x2551_y1151_class0.png    1316      0
# data/12910/0/12910_idx5_x2001_y101_class0.png     1225      0
# ...                                                ...    ...
# data/13666/1/13666_idx5_x901_y1101_class1.png     1333      1
# data/13666/1/13666_idx5_x1051_y1001_class1.png    1263      1
# data/13666/1/13666_idx5_x1051_y1151_class1.png    1397      1
# data/13666/1/13666_idx5_x1051_y1051_class1.png    1361      1
# data/13666/1/13666_idx5_x901_y1151_class1.png     1308      1
#
# [277523 rows x 8 columns]>

# %% [markdown]
# ## Splitting in train and test set.

# %%
X= df[['red','green','blue','gray','gray_var','edges','ridges']]
y=df['group']
  
# using the train test split function
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.125, shuffle=False)

print('X_train : ')
print(X_train.head())
print(X_train.shape)
print('')
print('X_val : ')
print(X_val.head())
print(X_val.shape)
print('')
print('X_test : ')
print(X_test.head())
print(X_test.shape)
print('')
print('y_train : ')
print(y_train.head())
print(y_train.shape)
print('')
print('y_val : ')
print(y_val.head())
print(y_val.shape)
print('')
print('y_test : ')
print(y_test.head())
print(y_test.shape)



#Split: 70% train, 10% validation and 20% test.
# Out:
# X_train :
#                                                    red   green    blue  \
# data/12910/0/12910_idx5_x3001_y701_class0.png   2.8792  2.7112  2.8076
# data/12910/0/12910_idx5_x1501_y401_class0.png   2.7392  2.7464  2.0908
# data/12910/0/12910_idx5_x2251_y1101_class0.png  1.1296  2.6620  2.2704
# data/12910/0/12910_idx5_x2551_y1151_class0.png  1.9812  2.8940  2.2452
# data/12910/0/12910_idx5_x2001_y101_class0.png   2.8660  3.0032  2.5404
#
#                                                     gray  gray_var  edges  \
# data/12910/0/12910_idx5_x3001_y701_class0.png   0.755730  0.003960     83
# data/12910/0/12910_idx5_x1501_y401_class0.png   0.483340  0.009377    350
# data/12910/0/12910_idx5_x2251_y1101_class0.png  0.799321  0.001401     14
# data/12910/0/12910_idx5_x2551_y1151_class0.png  0.824825  0.001107      0
# data/12910/0/12910_idx5_x2001_y101_class0.png   0.675241  0.005805    187
#
#                                                 ridges
# data/12910/0/12910_idx5_x3001_y701_class0.png     1292
# data/12910/0/12910_idx5_x1501_y401_class0.png     1297
# data/12910/0/12910_idx5_x2251_y1101_class0.png    1315
# data/12910/0/12910_idx5_x2551_y1151_class0.png    1316
# data/12910/0/12910_idx5_x2001_y101_class0.png     1225
# (194265, 7)
#
# X_val :
#                                                    red   green    blue  \
# data/10277/0/10277_idx5_x301_y2051_class0.png   1.8916  3.3608  3.1964
# data/10277/0/10277_idx5_x1701_y1251_class0.png  1.9904  2.1932  2.2724
# data/10277/0/10277_idx5_x751_y551_class0.png    3.0532  2.3560  2.4284
# data/10277/0/10277_idx5_x501_y1901_class0.png   1.9820  2.4620  2.7300
# data/10277/0/10277_idx5_x901_y751_class0.png    2.5864  2.2684  2.3436
#
#                                                     gray  gray_var  edges  \
# data/10277/0/10277_idx5_x301_y2051_class0.png   0.867761  0.030824    181
# data/10277/0/10277_idx5_x1701_y1251_class0.png  0.480924  0.015185    507
# data/10277/0/10277_idx5_x751_y551_class0.png    0.807837  0.022346    474
# data/10277/0/10277_idx5_x501_y1901_class0.png   0.703649  0.039559    499
# data/10277/0/10277_idx5_x901_y751_class0.png    0.695074  0.033165    507
#
#                                                 ridges
# data/10277/0/10277_idx5_x301_y2051_class0.png     1597
# data/10277/0/10277_idx5_x1701_y1251_class0.png    1233
# data/10277/0/10277_idx5_x751_y551_class0.png      1389
# data/10277/0/10277_idx5_x501_y1901_class0.png     1327
# data/10277/0/10277_idx5_x901_y751_class0.png      1300
# (27753, 7)
#
# X_test :
#                                                 red   green    blue      gray  \
# data/9257/0/9257_idx5_x301_y1001_class0.png  2.5784  2.7000  2.2112  0.609239
# data/9257/0/9257_idx5_x2351_y251_class0.png  2.4596  2.0084  2.7724  0.501843
# data/9257/0/9257_idx5_x1101_y401_class0.png  2.3712  2.5872  2.7416  0.593688
# data/9257/0/9257_idx5_x751_y1001_class0.png  2.8744  2.5176  2.3424  0.599057
# data/9257/0/9257_idx5_x1201_y551_class0.png  2.7900  2.2444  2.4596  0.641368
#
#                                              gray_var  edges  ridges
# data/9257/0/9257_idx5_x301_y1001_class0.png  0.003757     51    1260
# data/9257/0/9257_idx5_x2351_y251_class0.png  0.024991    479    1183
# data/9257/0/9257_idx5_x1101_y401_class0.png  0.027011    504    1264
# data/9257/0/9257_idx5_x751_y1001_class0.png  0.002871     33    1245
# data/9257/0/9257_idx5_x1201_y551_class0.png  0.031924    280    1333
# (55505, 7)
#
# y_train :
# data/12910/0/12910_idx5_x3001_y701_class0.png     0
# data/12910/0/12910_idx5_x1501_y401_class0.png     0
# data/12910/0/12910_idx5_x2251_y1101_class0.png    0
# data/12910/0/12910_idx5_x2551_y1151_class0.png    0
# data/12910/0/12910_idx5_x2001_y101_class0.png     0
# Name: group, dtype: int64
# (194265,)
#
# y_val :
# data/10277/0/10277_idx5_x301_y2051_class0.png     0
# data/10277/0/10277_idx5_x1701_y1251_class0.png    0
# data/10277/0/10277_idx5_x751_y551_class0.png      0
# data/10277/0/10277_idx5_x501_y1901_class0.png     0
# data/10277/0/10277_idx5_x901_y751_class0.png      0
# Name: group, dtype: int64
# (27753,)
#
# y_test :
# data/9257/0/9257_idx5_x301_y1001_class0.png    0
# data/9257/0/9257_idx5_x2351_y251_class0.png    0
# data/9257/0/9257_idx5_x1101_y401_class0.png    0
# data/9257/0/9257_idx5_x751_y1001_class0.png    0
# data/9257/0/9257_idx5_x1201_y551_class0.png    0
# Name: group, dtype: int64
# (55505,)

# %% [markdown]
# ## Single decision tree classifier

# %%
#Single decision tree with different depths, to see what is proper.
acc_for_depths = []
bal_accs = []

st = time.time()
for d in range(1,50):
    model = DecisionTreeClassifier(max_depth = d)
    model = model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    accuracy = model.score(X_val, y_val)
    balanced_accuracy = balanced_accuracy_score(y_val, y_pred)
    acc_for_depths.append(accuracy)
    bal_accs.append(balanced_accuracy)
    print(f'Accuracy and balancend accuracy for max_depth of {d} is: {accuracy} , {balanced_accuracy}')
    
et = time.time()
elapsed_time = et - st
print(f'Execution time: {elapsed_time}s')
    
plt.plot(range(1,50), acc_for_depths, label='Accuracy')
plt.plot(range(1,50), bal_accs, label='Balanced accuracy')
plt.legend()
plt.show()
#Observing in the plot that max_depth = 11 gives the highest accuracy when validating.
# Out:
# Accuracy and balancend accuracy for max_depth of 1 is: 0.6743775447699348 , 0.6910898622593671
# Accuracy and balancend accuracy for max_depth of 2 is: 0.7307678449176666 , 0.6279309405299985
# Accuracy and balancend accuracy for max_depth of 3 is: 0.7611069073613663 , 0.6324538093264291
# Accuracy and balancend accuracy for max_depth of 4 is: 0.7845277987965265 , 0.6755620317682303
# Accuracy and balancend accuracy for max_depth of 5 is: 0.7894281699275754 , 0.6556362113575418
# Accuracy and balancend accuracy for max_depth of 6 is: 0.7789067848520881 , 0.6725507266021542
# Accuracy and balancend accuracy for max_depth of 7 is: 0.7786905920080712 , 0.6923540581623155
# Accuracy and balancend accuracy for max_depth of 8 is: 0.7880589485821352 , 0.6908705346625522
# Accuracy and balancend accuracy for max_depth of 9 is: 0.7859690844233056 , 0.6954887484388006
# Accuracy and balancend accuracy for max_depth of 10 is: 0.7940402839332684 , 0.6957826363219817
# Accuracy and balancend accuracy for max_depth of 11 is: 0.7935718661045653 , 0.691336120331681
# Accuracy and balancend accuracy for max_depth of 12 is: 0.786833855799373 , 0.6881730058132269
# Accuracy and balancend accuracy for max_depth of 13 is: 0.7831946095917558 , 0.6854909694561461
# Accuracy and balancend accuracy for max_depth of 14 is: 0.7733578351889886 , 0.6796793216285776
# Accuracy and balancend accuracy for max_depth of 15 is: 0.7691060425899903 , 0.6746267205628991
# Accuracy and balancend accuracy for max_depth of 16 is: 0.766439664180449 , 0.6754109906386082
# Accuracy and balancend accuracy for max_depth of 17 is: 0.759341332468562 , 0.668489260928737
# Accuracy and balancend accuracy for max_depth of 18 is: 0.754585089900191 , 0.6661508335387618
# Accuracy and balancend accuracy for max_depth of 19 is: 0.7483515295643715 , 0.6637414735809901
# Accuracy and balancend accuracy for max_depth of 20 is: 0.7463697618275502 , 0.6609351131745764
# Accuracy and balancend accuracy for max_depth of 21 is: 0.7416135192591792 , 0.6585347584946658
# Accuracy and balancend accuracy for max_depth of 22 is: 0.7402082657730695 , 0.659128850759243
# Accuracy and balancend accuracy for max_depth of 23 is: 0.737145533816164 , 0.6560077750971546
# Accuracy and balancend accuracy for max_depth of 24 is: 0.7326054840918099 , 0.6538066035062369
# Accuracy and balancend accuracy for max_depth of 25 is: 0.7296868806975823 , 0.6492907767517356
# Accuracy and balancend accuracy for max_depth of 26 is: 0.7279573379454474 , 0.6496170580277912
# Accuracy and balancend accuracy for max_depth of 27 is: 0.7281014665081252 , 0.6510709622724098
# Accuracy and balancend accuracy for max_depth of 28 is: 0.7257233452239398 , 0.6467744204356813
# Accuracy and balancend accuracy for max_depth of 29 is: 0.7248225417072028 , 0.6483699764206828
# Accuracy and balancend accuracy for max_depth of 30 is: 0.7215436169062804 , 0.6451735722494722
# Accuracy and balancend accuracy for max_depth of 31 is: 0.7232371275177458 , 0.6473634338942611
# Accuracy and balancend accuracy for max_depth of 32 is: 0.7213994883436025 , 0.6443389409042084
# Accuracy and balancend accuracy for max_depth of 33 is: 0.7203545562641877 , 0.6438613197452367
# Accuracy and balancend accuracy for max_depth of 34 is: 0.7219039383129752 , 0.6452784773346973
# Accuracy and balancend accuracy for max_depth of 35 is: 0.7219039383129752 , 0.6442257134057944
# Accuracy and balancend accuracy for max_depth of 36 is: 0.7218679061723057 , 0.6463083652970905
# Accuracy and balancend accuracy for max_depth of 37 is: 0.7202824919828487 , 0.6437536405222822
# Accuracy and balancend accuracy for max_depth of 38 is: 0.7213274240622636 , 0.6455317347698986
# Accuracy and balancend accuracy for max_depth of 39 is: 0.7190573992000865 , 0.6434712759804401
# Accuracy and balancend accuracy for max_depth of 40 is: 0.7209671026555687 , 0.64561261155448
# Accuracy and balancend accuracy for max_depth of 41 is: 0.721435520484272 , 0.6456622899593627
# Accuracy and balancend accuracy for max_depth of 42 is: 0.720606781248874 , 0.6458173429189323
# Accuracy and balancend accuracy for max_depth of 43 is: 0.7185169170900443 , 0.6424469362935061
# Accuracy and balancend accuracy for max_depth of 44 is: 0.7209310705148992 , 0.6449085353986803
# Accuracy and balancend accuracy for max_depth of 45 is: 0.7212553597809246 , 0.6440616551683637
# Accuracy and balancend accuracy for max_depth of 46 is: 0.7220120347349837 , 0.6460902327134516
# Accuracy and balancend accuracy for max_depth of 47 is: 0.7205707491082045 , 0.6460421761121646
# Accuracy and balancend accuracy for max_depth of 48 is: 0.7209310705148992 , 0.6442892624993257
# Accuracy and balancend accuracy for max_depth of 49 is: 0.7185889813713833 , 0.6430500338359445
# Execution time: 215.51437854766846s

# %% [markdown]
# ### Final test of decision tree with max_depth = 10

# %%
st = time.time()
depth = 10
model = DecisionTreeClassifier(max_depth = depth)
model.fit(X_train, y_train)

predicted_value = model.predict(X_test)

#To plot the actual decision tree
#tree.plot_tree(model)

accuracy = model.score(X_test, y_test)
balanced_accuracy = balanced_accuracy_score(y_test, predicted_value)

print(f'Accuracy for max_depth of {depth} is: {accuracy}')
print(f'Balanced accuracy for max_depth of {depth} is: {balanced_accuracy}')
    
et = time.time()
elapsed_time = et - st
print(f'Execution time: {elapsed_time}s')

ConfusionMatrixDisplay(confusion_matrix(y_test, predicted_value)).plot()
# Out:
# Accuracy for max_depth of 10 is: 0.7990991802540311
# Balanced accuracy for max_depth of 10 is: 0.7284824557294114
# Execution time: 2.8073630332946777s

# %% [markdown]
# ## Random forest classifier

# %%
#Random forest classification with different values for max_depth
acc_for_depths = []
bal_accs = []
for i in range(1,50):
    model = RandomForestClassifier(max_depth = i)

    # fit the regressor with x and y data
    model.fit(X_train, y_train) 

    y_pred = model.predict(X_val)  # test the output by changing values
    #print(y_pred)

    #print("accuracy on training set: %f" % regressor.score(X_train, y_train))
    #print("accuracy on validation set: %f" % regressor.score(X_val, y_val))

    # Create confusion matrix
    #confusion = confusion_matrix(y_val, y_pred)
    #ConfusionMatrixDisplay(confusion).plot()
    # Display accuracy score
    accuracy = model.score(X_val, y_val)
    balanced_accuracy = balanced_accuracy_score(y_val, y_pred)
    print(f'Accuracy and balancend accuracy for max_depth of {i} is: {accuracy} , {balanced_accuracy}')
    acc_for_depths.append(accuracy)
    bal_accs.append(balanced_accuracy)
    
plt.plot(range(1,50), acc_for_depths, label='Accuracy')
plt.plot(range(1,50), bal_accs, label='Balanced accuracy')
plt.legend()
plt.show()
# Out:
# Accuracy and balancend accuracy for max_depth of 1 is: 0.7875544986127626 , 0.5
# Accuracy and balancend accuracy for max_depth of 2 is: 0.7875544986127626 , 0.5
# Accuracy and balancend accuracy for max_depth of 3 is: 0.7954455374193781 , 0.5271798064624946
# Accuracy and balancend accuracy for max_depth of 4 is: 0.7934277375418873 , 0.6494436957592056
# Accuracy and balancend accuracy for max_depth of 5 is: 0.7951933124346917 , 0.6670372772410083
# Accuracy and balancend accuracy for max_depth of 6 is: 0.7955536338413866 , 0.6743257479587468
# Accuracy and balancend accuracy for max_depth of 7 is: 0.7944006053399633 , 0.6834401561301786
# Accuracy and balancend accuracy for max_depth of 8 is: 0.7956256981227254 , 0.6895436859259543
# Accuracy and balancend accuracy for max_depth of 9 is: 0.7977515944222247 , 0.691326858979568
# Accuracy and balancend accuracy for max_depth of 10 is: 0.7973912730155298 , 0.6920889359534396
# Accuracy and balancend accuracy for max_depth of 11 is: 0.7993370086116817 , 0.6961728934819884
# Accuracy and balancend accuracy for max_depth of 12 is: 0.7982200122509279 , 0.6973834845081907
# Accuracy and balancend accuracy for max_depth of 13 is: 0.8000936835657406 , 0.6963436523290124
# Accuracy and balancend accuracy for max_depth of 14 is: 0.798832558642309 , 0.6977104486489181
# Accuracy and balancend accuracy for max_depth of 15 is: 0.8003098764097575 , 0.697967163086521
# Accuracy and balancend accuracy for max_depth of 16 is: 0.7981839801102584 , 0.6953170079738108
# Accuracy and balancend accuracy for max_depth of 17 is: 0.7994811371743595 , 0.6973790885668651
# Accuracy and balancend accuracy for max_depth of 18 is: 0.7984362050949447 , 0.6957248488991197
# Accuracy and balancend accuracy for max_depth of 19 is: 0.7994090728930205 , 0.6973952639237814
# Accuracy and balancend accuracy for max_depth of 20 is: 0.7984722372356141 , 0.6961812158951775
# Accuracy and balancend accuracy for max_depth of 21 is: 0.7987244622203005 , 0.696650984110422
# Accuracy and balancend accuracy for max_depth of 22 is: 0.7975354015782078 , 0.695276804316251
# Accuracy and balancend accuracy for max_depth of 23 is: 0.7982560443915973 , 0.6961058873860555
# Accuracy and balancend accuracy for max_depth of 24 is: 0.7986884300796311 , 0.6968758173036542
# Accuracy and balancend accuracy for max_depth of 25 is: 0.7986163657982921 , 0.6964585016310223
# Accuracy and balancend accuracy for max_depth of 26 is: 0.797859690844233 , 0.6961019609141919
# Accuracy and balancend accuracy for max_depth of 27 is: 0.7965985659208014 , 0.6932577015184862
# Accuracy and balancend accuracy for max_depth of 28 is: 0.7983641408136057 , 0.695617169676165
# Accuracy and balancend accuracy for max_depth of 29 is: 0.7977876265628941 , 0.6941983902831088
# Accuracy and balancend accuracy for max_depth of 30 is: 0.797175080171513 , 0.6951099719410907
# Accuracy and balancend accuracy for max_depth of 31 is: 0.7966706302021404 , 0.6955328358891819
# Accuracy and balancend accuracy for max_depth of 32 is: 0.7987965265016395 , 0.6973160089427957
# Accuracy and balancend accuracy for max_depth of 33 is: 0.7980758836882499 , 0.6959295802635721
# Accuracy and balancend accuracy for max_depth of 34 is: 0.7969588873274961 , 0.6944772978225495
# Accuracy and balancend accuracy for max_depth of 35 is: 0.7982920765322667 , 0.6958191269028877
# Accuracy and balancend accuracy for max_depth of 36 is: 0.7961661802327676 , 0.6924877716008875
# Accuracy and balancend accuracy for max_depth of 37 is: 0.7978236587035635 , 0.6953978847583923
# Accuracy and balancend accuracy for max_depth of 38 is: 0.7991208157676648 , 0.6950448010439635
# Accuracy and balancend accuracy for max_depth of 39 is: 0.7991208157676648 , 0.6967787651621564
# Accuracy and balancend accuracy for max_depth of 40 is: 0.7986163657982921 , 0.6948483920927002
# Accuracy and balancend accuracy for max_depth of 41 is: 0.7968868230461572 , 0.6918925270021763
# Accuracy and balancend accuracy for max_depth of 42 is: 0.7974993694375383 , 0.6937057461013549
# Accuracy and balancend accuracy for max_depth of 43 is: 0.797175080171513 , 0.6936237169826396
# Accuracy and balancend accuracy for max_depth of 44 is: 0.7980758836882499 , 0.6938240524057664
# Accuracy and balancend accuracy for max_depth of 45 is: 0.799373040752351 , 0.6948333690699178
# Accuracy and balancend accuracy for max_depth of 46 is: 0.7978236587035635 , 0.6942831935395539
# Accuracy and balancend accuracy for max_depth of 47 is: 0.7995532014556985 , 0.6956289490917559
# Accuracy and balancend accuracy for max_depth of 48 is: 0.79944510503369 , 0.6959318849318399
# Accuracy and balancend accuracy for max_depth of 49 is: 0.7989766872049868 , 0.6957583519470862

# %% [markdown]
# ### Final test of random forest

# %%
depth = 15 #As found optimal above
model = RandomForestClassifier(max_depth = depth)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = model.score(X_test, y_test)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
print(f'Accuracy and balanced accuracy for random forest with max_depth = {depth}: {accuracy} , {balanced_accuracy}')

# Create confusion matrix
confusion = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(confusion).plot()
# Out:
# Accuracy and balanced accuracy for random forest with max_depth = 15: 0.8034951806143591 , 0.7305675493670385

# %% [markdown]
# ### Feature importance for the random forest

# %%
plt.plot(model.feature_importances_, 'o')
plt.xticks(range(X_test.shape[1]), X_test.columns, rotation=90)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)
